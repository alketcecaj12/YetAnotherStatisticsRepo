# %%
import pandas as pd 
import matplotlib.pyplot as plt
import empiricaldist as ed
import seaborn as sns
from empiricaldist import Pmf
from empiricaldist import Cdf

# %%
s = pd.Series([1, 2, 1, 3, 4, 5, 1, 9, 10, 12, 20])

# %%
plt.hist(s)
plt.show()

# %%
plt.figure(figsize = (20, 2))
plt.boxplot(s, vert = False)
plt.show()

# %%
sns.kdeplot(s.values)
plt.show()
# Out:
# /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
a = Pmf.from_seq(s)

# %%
a
# Out:
# 1     0.272727
# 2     0.090909
# 3     0.090909
# 4     0.090909
# 5     0.090909
# 9     0.090909
# 10    0.090909
# 12    0.090909
# 20    0.090909
# Name: proportion, dtype: float64

# %%
cdf = Cdf.from_seq(s)

# %%
plt.plot(cdf)
plt.show()
